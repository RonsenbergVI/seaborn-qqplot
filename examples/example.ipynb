# %%
import os,sys
from scipy.stats import gamma
from seaborn import load_dataset

# %%
sys.path.append(os.path.abspath('..'))

# %%
from seaborn_qqplot import pplot

# %%
# %matplotlib inline

# %%
iris = load_dataset('iris')

# %%
pplot(iris, x="sepal_length", y = gamma, height = 5, aspect=3)

# %%
pplot(iris, x="sepal_length", y = "petal_length", hue = "species", height = 5, aspect=3)

# %%
pplot(iris, x="petal_length", y=gamma, hue="species", height=5, aspect=3, display_kws={"identity":False,"fit":True,"reg":True,"ci":0.025})

# %%
pplot(iris, x="petal_length", y = gamma, hue = "species", height = 5, aspect=3)
